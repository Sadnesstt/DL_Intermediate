# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from utils import load_mnist
from trainer import Trainer

# %%
from argparse import Namespace

config = {
    'train_ratio' : .8,
    'batch_size' : 256,
    'n_epochs' : 50,
    'verbose' : 1,
    'btl_size' : 2
}

config = Namespace(**config)

print(config)
# Out:
# Namespace(train_ratio=0.8, batch_size=256, n_epochs=50, verbose=1, btl_size=2)

# %%
def show_image(x):
    if x.dim() == 1:
        x = x.view(int(x.size(0) ** .5), -1)
        
        plt.imshow(x, cmap = 'gray')
        plt.show()

# %%
train_x, train_y = load_mnist(flatten = True)
test_x, test_y = load_mnist(is_train=False, flatten = True)

train_cnt = int(train_x.size(0) * config.train_ratio)
valid_cnt = train_x.size(0) - train_cnt

# Shuffle dataset to split into train/valid set.
indices = torch.randperm(train_x.size(0))
train_x, valid_x = torch.index_select(
    train_x,
    dim = 0,
    index=indices
).split([train_cnt, valid_cnt], dim = 0)
train_y, valid_y = torch.index_select(
    train_y,
    dim = 0,
    index=indices
).split([train_cnt, valid_cnt], dim = 0)

print('Train:', train_x.shape, train_y.shape)
print('Valid:', valid_x.shape, valid_y.shape)
print('Test:', test_x.shape, test_y.shape)
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# Test: torch.Size([10000, 784]) torch.Size([10000])

# %%
from model import Autoencoder

# %%
model = Autoencoder(btl_size=config.btl_size)
optimizer = optim.Adam(model.parameters())
crit = nn.MSELoss()

trainer = Trainer(model, optimizer, crit)

# %%
trainer.train((train_x, train_x), (valid_x, valid_x), config)
# y는 사실 필요없다. autoencoder에서는 x를 넣어서 x_hat만 뱉어내면됨
# Out:
# Epoch(1/50): train_loss = 7.4515e-02 valid_loss=5.1713e-02 lowest_loss=5.1713e-02
# Epoch(2/50): train_loss = 4.9025e-02 valid_loss=4.6766e-02 lowest_loss=4.6766e-02
# Epoch(3/50): train_loss = 4.5972e-02 valid_loss=4.4127e-02 lowest_loss=4.4127e-02
# Epoch(4/50): train_loss = 4.4036e-02 valid_loss=4.3050e-02 lowest_loss=4.3050e-02
# Epoch(5/50): train_loss = 4.3061e-02 valid_loss=4.1362e-02 lowest_loss=4.1362e-02
# Epoch(6/50): train_loss = 4.2135e-02 valid_loss=4.1093e-02 lowest_loss=4.1093e-02
# Epoch(7/50): train_loss = 4.1403e-02 valid_loss=3.9935e-02 lowest_loss=3.9935e-02
# Epoch(8/50): train_loss = 4.0620e-02 valid_loss=3.9480e-02 lowest_loss=3.9480e-02
# Epoch(9/50): train_loss = 4.0500e-02 valid_loss=3.8996e-02 lowest_loss=3.8996e-02
# Epoch(10/50): train_loss = 4.0353e-02 valid_loss=3.9412e-02 lowest_loss=3.8996e-02
# Epoch(11/50): train_loss = 3.9643e-02 valid_loss=3.8977e-02 lowest_loss=3.8977e-02
# Epoch(12/50): train_loss = 3.9344e-02 valid_loss=3.8329e-02 lowest_loss=3.8329e-02
# Epoch(13/50): train_loss = 3.9113e-02 valid_loss=3.8157e-02 lowest_loss=3.8157e-02
# Epoch(14/50): train_loss = 3.8867e-02 valid_loss=3.7855e-02 lowest_loss=3.7855e-02
# Epoch(15/50): train_loss = 3.8729e-02 valid_loss=3.7820e-02 lowest_loss=3.7820e-02
# Epoch(16/50): train_loss = 3.8977e-02 valid_loss=3.7880e-02 lowest_loss=3.7820e-02
# Epoch(17/50): train_loss = 3.8726e-02 valid_loss=3.7670e-02 lowest_loss=3.7670e-02
# Epoch(18/50): train_loss = 3.8446e-02 valid_loss=3.8528e-02 lowest_loss=3.7670e-02
# Epoch(19/50): train_loss = 3.8331e-02 valid_loss=3.7010e-02 lowest_loss=3.7010e-02
# Epoch(20/50): train_loss = 3.7983e-02 valid_loss=3.8397e-02 lowest_loss=3.7010e-02
# Epoch(21/50): train_loss = 3.8013e-02 valid_loss=3.6903e-02 lowest_loss=3.6903e-02
# Epoch(22/50): train_loss = 3.8155e-02 valid_loss=3.6630e-02 lowest_loss=3.6630e-02
# Epoch(23/50): train_loss = 3.8187e-02 valid_loss=3.7412e-02 lowest_loss=3.6630e-02
# Epoch(24/50): train_loss = 3.7688e-02 valid_loss=3.6831e-02 lowest_loss=3.6630e-02
# Epoch(25/50): train_loss = 3.7592e-02 valid_loss=3.6158e-02 lowest_loss=3.6158e-02
# Epoch(26/50): train_loss = 3.7451e-02 valid_loss=3.7270e-02 lowest_loss=3.6158e-02
# Epoch(27/50): train_loss = 3.8445e-02 valid_loss=3.7941e-02 lowest_loss=3.6158e-02
# Epoch(28/50): train_loss = 3.9887e-02 valid_loss=3.8161e-02 lowest_loss=3.6158e-02
# Epoch(29/50): train_loss = 3.8773e-02 valid_loss=3.7835e-02 lowest_loss=3.6158e-02
# Epoch(30/50): train_loss = 3.8561e-02 valid_loss=3.6935e-02 lowest_loss=3.6158e-02
# Epoch(31/50): train_loss = 3.7748e-02 valid_loss=3.7645e-02 lowest_loss=3.6158e-02
# Epoch(32/50): train_loss = 3.7735e-02 valid_loss=3.8794e-02 lowest_loss=3.6158e-02
# Epoch(33/50): train_loss = 3.7377e-02 valid_loss=3.7545e-02 lowest_loss=3.6158e-02
# Epoch(34/50): train_loss = 3.7112e-02 valid_loss=7.6047e-02 lowest_loss=3.6158e-02
# Epoch(35/50): train_loss = 3.6921e-02 valid_loss=4.8306e-02 lowest_loss=3.6158e-02
# Epoch(36/50): train_loss = 3.6884e-02 valid_loss=4.8664e-02 lowest_loss=3.6158e-02
# Epoch(37/50): train_loss = 3.6479e-02 valid_loss=4.1911e-02 lowest_loss=3.6158e-02
# Epoch(38/50): train_loss = 3.6613e-02 valid_loss=7.1593e-02 lowest_loss=3.6158e-02
# Epoch(39/50): train_loss = 3.6533e-02 valid_loss=5.0997e-02 lowest_loss=3.6158e-02
# Epoch(40/50): train_loss = 3.6406e-02 valid_loss=4.5014e-02 lowest_loss=3.6158e-02
# Epoch(41/50): train_loss = 3.6275e-02 valid_loss=5.1979e-02 lowest_loss=3.6158e-02
# Epoch(42/50): train_loss = 3.6471e-02 valid_loss=5.0953e-02 lowest_loss=3.6158e-02
# Epoch(43/50): train_loss = 3.6762e-02 valid_loss=3.5777e-02 lowest_loss=3.5777e-02
# Epoch(44/50): train_loss = 3.6366e-02 valid_loss=3.8570e-02 lowest_loss=3.5777e-02
# Epoch(45/50): train_loss = 3.6292e-02 valid_loss=3.8508e-02 lowest_loss=3.5777e-02
# Epoch(46/50): train_loss = 3.6146e-02 valid_loss=3.7342e-02 lowest_loss=3.5777e-02
# Epoch(47/50): train_loss = 3.6122e-02 valid_loss=3.7897e-02 lowest_loss=3.5777e-02
# Epoch(48/50): train_loss = 3.5872e-02 valid_loss=3.6205e-02 lowest_loss=3.5777e-02
# Epoch(49/50): train_loss = 3.5776e-02 valid_loss=3.6404e-02 lowest_loss=3.5777e-02
# Epoch(50/50): train_loss = 3.5864e-02 valid_loss=5.9946e-02 lowest_loss=3.5777e-02

# %% [markdown]
# ## Test

# %%
with torch.no_grad():
    import random
    
    index = int(random.random() * test_x.size(0))
    
    recon = model(test_x[index].view(1, -1)).squeeze()
    
    show_image(test_x[index])
    show_image(recon)

# %% [markdown]
# ## Latent Space

# %%
if config.btl_size == 2:
    color_map = [
        'brown', 'red', 'orange', 'yellow', 'green',
        'blue', 'navy', 'purple', 'gray', 'black',
    ]
    
    plt.figure(figsize=(20, 10))
    
    with torch.no_grad():
        latents = model.encoder(test_x[:1000])
        
        for i in range(10):
            target_latents = latents[test_y[:1000] == i]
            target_y = test_y[:1000][test_y][:1000 == i]
            plt.scatter(target_latents[:, 0],
                        target_latents[:, 1],
                        marker = 'o',
                        color = color_map[i],
                        label = i
                       )
        plt.legend()
        plt.grid(axis = 'both')
        plt.show()

# %%
if config.btl_size == 2:
    min_range, max_range = -2., 2.
    n = 20
    step = (max_range - min_range) / float(n)
    
    with torch.no_grad():
        lines = []
        
        for v1 in np.arange(min_range, max_range, step):
            z = torch.stack([
                torch.FloatTensor([v1] * n),
                torch.FloatTensor([v2 for v2 in np.arange(min_range,
                                                         max_range, step)]),
            ], dim = -1)
            
            line = torch.clamp(model.decoder(z).view(n, 28, 28), 0, 1)
            line = torch.cat([line[i] for i in range(n - 1, 0, -1)], dim = 0)
            lines += [line]
            
        lines = torch.cat(lines, dim = -1)
        plt.figure(figsize=(20, 20))
        show_image(lines)
